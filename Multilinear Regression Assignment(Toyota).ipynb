# %% [markdown]
# Name : Pradyumna PS
# Email ID : pradyumnaps193@gmail.com

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import statsmodels.api as sma
from statsmodels.graphics.regressionplots import influence_plot

# %%
toyota = pd.read_csv("ToyotaCorolla.csv", encoding='latin1')
toyota.head()
# Out:
#    Id                                           Model  Price  Age_08_04  \
# 0   1   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500         23
# 1   2   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750         23
# 2   3   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950         24
# 3   4   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950         26
# 4   5     TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750         30
#
#    Mfg_Month  Mfg_Year     KM Fuel_Type  HP  Met_Color  ... Central_Lock  \
# 0         10      2002  46986    Diesel  90          1  ...            1
# 1         10      2002  72937    Diesel  90          1  ...            1
# 2          9      2002  41711    Diesel  90          1  ...            0
# 3          7      2002  48000    Diesel  90          0  ...            0
# 4          3      2002  38500    Diesel  90          0  ...            1
#
#    Powered_Windows  Power_Steering  Radio  Mistlamps  Sport_Model  \
# ...

# %%
toyota.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 38 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                1436 non-null   int64
#  1   Model             1436 non-null   object
#  2   Price             1436 non-null   int64
#  3   Age_08_04         1436 non-null   int64
#  4   Mfg_Month         1436 non-null   int64
#  5   Mfg_Year          1436 non-null   int64
#  6   KM                1436 non-null   int64
#  7   Fuel_Type         1436 non-null   object
#  8   HP                1436 non-null   int64
#  9   Met_Color         1436 non-null   int64
#  10  Color             1436 non-null   object
#  11  Automatic         1436 non-null   int64
#  12  cc                1436 non-null   int64
#  13  Doors             1436 non-null   int64
#  14  Cylinders         1436 non-null   int64
#  15  Gears             1436 non-null   int64
# ...

# %%
toyota2=pd.concat([toyota.iloc[:,2:4],toyota.iloc[:,6:7],toyota.iloc[:,8:9],toyota.iloc[:,12:14],toyota.iloc[:,15:18]],axis=1)
toyota2
# Out:
#       Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500         23  46986   90  2000      3      5            210    1165
# 1     13750         23  72937   90  2000      3      5            210    1165
# 2     13950         24  41711   90  2000      3      5            210    1165
# 3     14950         26  48000   90  2000      3      5            210    1165
# 4     13750         30  38500   90  2000      3      5            210    1170
# ...     ...        ...    ...  ...   ...    ...    ...            ...     ...
# 1431   7500         69  20544   86  1300      3      5             69    1025
# 1432  10845         72  19000   86  1300      3      5             69    1015
# 1433   8500         71  17016   86  1300      3      5             69    1015
# 1434   7250         70  16916   86  1300      3      5             69    1015
# 1435   6950         76      1  110  1600      5      5             19    1114
#
# [1436 rows x 9 columns]

# %%
toyota3=toyota2.rename({'Age_08_04':'Age','cc':'CC','Quarterly_Tax':'QTax'},axis=1)
toyota3
# Out:
#       Price  Age     KM   HP    CC  Doors  Gears  QTax  Weight
# 0     13500   23  46986   90  2000      3      5   210    1165
# 1     13750   23  72937   90  2000      3      5   210    1165
# 2     13950   24  41711   90  2000      3      5   210    1165
# 3     14950   26  48000   90  2000      3      5   210    1165
# 4     13750   30  38500   90  2000      3      5   210    1170
# ...     ...  ...    ...  ...   ...    ...    ...   ...     ...
# 1431   7500   69  20544   86  1300      3      5    69    1025
# 1432  10845   72  19000   86  1300      3      5    69    1015
# 1433   8500   71  17016   86  1300      3      5    69    1015
# 1434   7250   70  16916   86  1300      3      5    69    1015
# 1435   6950   76      1  110  1600      5      5    19    1114
#
# [1436 rows x 9 columns]

# %%
toyota3[toyota3.duplicated()]
# Out:
#      Price  Age     KM   HP    CC  Doors  Gears  QTax  Weight
# 113  24950    8  13253  116  2000      5      5   234    1320

# %%
toyota4 = toyota3.drop_duplicates().reset_index(drop = True)
toyota4
# Out:
#       Price  Age     KM   HP    CC  Doors  Gears  QTax  Weight
# 0     13500   23  46986   90  2000      3      5   210    1165
# 1     13750   23  72937   90  2000      3      5   210    1165
# 2     13950   24  41711   90  2000      3      5   210    1165
# 3     14950   26  48000   90  2000      3      5   210    1165
# 4     13750   30  38500   90  2000      3      5   210    1170
# ...     ...  ...    ...  ...   ...    ...    ...   ...     ...
# 1430   7500   69  20544   86  1300      3      5    69    1025
# 1431  10845   72  19000   86  1300      3      5    69    1015
# 1432   8500   71  17016   86  1300      3      5    69    1015
# 1433   7250   70  16916   86  1300      3      5    69    1015
# 1434   6950   76      1  110  1600      5      5    19    1114
#
# [1435 rows x 9 columns]

# %%
toyota4.corr()
# Out:
#            Price       Age        KM        HP        CC     Doors     Gears  \
# Price   1.000000 -0.876273 -0.569420  0.314134  0.124375  0.183604  0.063831
# Age    -0.876273  1.000000  0.504575 -0.155293 -0.096549 -0.146929 -0.005629
# KM     -0.569420  0.504575  1.000000 -0.332904  0.103822 -0.035193  0.014890
# HP      0.314134 -0.155293 -0.332904  1.000000  0.035207  0.091803  0.209642
# CC      0.124375 -0.096549  0.103822  0.035207  1.000000  0.079254  0.014732
# Doors   0.183604 -0.146929 -0.035193  0.091803  0.079254  1.000000 -0.160101
# Gears   0.063831 -0.005629  0.014890  0.209642  0.014732 -0.160101  1.000000
# QTax    0.211508 -0.193319  0.283312 -0.302287  0.305982  0.107353 -0.005125
# Weight  0.575869 -0.466484 -0.023969  0.087143  0.335077  0.301734  0.021238
#
#             QTax    Weight
# Price   0.211508  0.575869
# Age    -0.193319 -0.466484
# KM      0.283312 -0.023969
# HP     -0.302287  0.087143
# CC      0.305982  0.335077
# Doors   0.107353  0.301734
# ...

# %%
sns.pairplot(toyota4)

# %%
model=smf.ols('Price~Age+KM+HP+CC+Doors+Gears+QTax+Weight',data=toyota4).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.863
# Model:                            OLS   Adj. R-squared:                  0.862
# Method:                 Least Squares   F-statistic:                     1118.
# Date:                Tue, 14 Feb 2023   Prob (F-statistic):               0.00
# Time:                        00:50:02   Log-Likelihood:                -12366.
# No. Observations:                1435   AIC:                         2.475e+04
# Df Residuals:                    1426   BIC:                         2.480e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -5472.5404   1412.169     -3.875      0.000   -8242.692   -2702.389
# ...

# %%
model.params
# Out:
# Intercept   -5472.540368
# Age          -121.713891
# KM             -0.020737
# HP             31.584612
# CC             -0.118558
# Doors          -0.920189
# Gears         597.715894
# QTax            3.858805
# Weight         16.855470
# dtype: float64

# %%
model.tvalues, model.pvalues
# Out:
# (Intercept    -3.875273
#  Age         -46.551876
#  KM          -16.552424
#  HP           11.209719
#  CC           -1.316436
#  Doors        -0.023012
#  Gears         3.034563
#  QTax          2.944198
#  Weight       15.760663
#  dtype: float64,
#  Intercept     1.113392e-04
#  Age          1.879217e-288
#  KM            1.994713e-56
#  HP            5.211155e-28
#  CC            1.882393e-01
#  Doors         9.816443e-01
#  Gears         2.452430e-03
#  QTax          3.290363e-03
#  Weight        1.031118e-51
#  dtype: float64)

# %%
slr_c=smf.ols('Price~CC',data=toyota4).fit()
slr_c.tvalues , slr_c.pvalues
# Out:
# (Intercept    24.879592
#  CC            4.745039
#  dtype: float64,
#  Intercept    7.236022e-114
#  CC            2.292856e-06
#  dtype: float64)

# %%
slr_d=smf.ols('Price~Doors',data=toyota4).fit()
slr_d.tvalues , slr_d.pvalues
# Out:
# (Intercept    19.421546
#  Doors         7.070520
#  dtype: float64,
#  Intercept    8.976407e-75
#  Doors        2.404166e-12
#  dtype: float64)

# %%
mlr_cd=smf.ols('Price~CC+Doors',data=toyota4).fit()
mlr_cd.tvalues , mlr_cd.pvalues
# Out:
# (Intercept    12.786341
#  CC            4.268006
#  Doors         6.752236
#  dtype: float64,
#  Intercept    1.580945e-35
#  CC           2.101878e-05
#  Doors        2.109558e-11
#  dtype: float64)

# %%
rsq_age=smf.ols('Age~KM+HP+CC+Doors+Gears+QTax+Weight',data=toyota4).fit().rsquared
vif_age=1/(1-rsq_age)

rsq_KM=smf.ols('KM~Age+HP+CC+Doors+Gears+QTax+Weight',data=toyota4).fit().rsquared
vif_KM=1/(1-rsq_KM)

rsq_HP=smf.ols('HP~Age+KM+CC+Doors+Gears+QTax+Weight',data=toyota4).fit().rsquared
vif_HP=1/(1-rsq_HP)

rsq_CC=smf.ols('CC~Age+KM+HP+Doors+Gears+QTax+Weight',data=toyota4).fit().rsquared
vif_CC=1/(1-rsq_CC)

rsq_DR=smf.ols('Doors~Age+KM+HP+CC+Gears+QTax+Weight',data=toyota4).fit().rsquared
vif_DR=1/(1-rsq_DR)

rsq_GR=smf.ols('Gears~Age+KM+HP+CC+Doors+QTax+Weight',data=toyota4).fit().rsquared
vif_GR=1/(1-rsq_GR)

rsq_QT=smf.ols('QTax~Age+KM+HP+CC+Doors+Gears+Weight',data=toyota4).fit().rsquared
vif_QT=1/(1-rsq_QT)

rsq_WT=smf.ols('Weight~Age+KM+HP+CC+Doors+Gears+QTax',data=toyota4).fit().rsquared
vif_WT=1/(1-rsq_WT)

# %%
d1={'Variables':['Age','KM','HP','CC','Doors','Gears','QT','Weight'],
    'Vif':[vif_age,vif_KM,vif_HP,vif_CC,vif_DR,vif_GR,vif_QT,vif_WT]}
Vif_df=pd.DataFrame(d1)
Vif_df
# Out:
#   Variables       Vif
# 0       Age  1.876236
# 1        KM  1.757178
# 2        HP  1.419180
# 3        CC  1.163470
# 4     Doors  1.155890
# 5     Gears  1.098843
# 6        QT  2.295375
# 7    Weight  2.487180

# %%
sma.qqplot(model.resid,line='q')
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
list(np.where(model.resid>6000))
# Out:
# [array([109, 146, 522], dtype=int64)]

# %%
list(np.where(model.resid<-6000))
# Out:
# [array([220, 600, 959], dtype=int64)]

# %%
def standard_values(vals) : return (vals-vals.mean())/vals.std()

# %%
plt.scatter(standard_values(model.fittedvalues),standard_values(model.resid))
plt.title('Residual Plot')
plt.xlabel('standardized fitted values')
plt.ylabel('standardized residual values')
plt.show()

# %%
fig=plt.figure(figsize=(15,8))
sma.graphics.plot_regress_exog(model,'KM',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
sma.graphics.plot_regress_exog(model,'Age',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
sma.graphics.plot_regress_exog(model,'CC',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
sma.graphics.plot_regress_exog(model,'HP',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
sma.graphics.plot_regress_exog(model,'Doors',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
sma.graphics.plot_regress_exog(model,'Gears',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
sma.graphics.plot_regress_exog(model,'Weight',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
sma.graphics.plot_regress_exog(model,'QTax',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %% [markdown]
# Cooks Distance

# %%
(c,_)=model.get_influence().cooks_distance
c
# Out:
# array([7.22221054e-03, 3.94547973e-03, 5.44224039e-03, ...,
#        8.04110551e-07, 6.99854767e-04, 1.08408002e-02])

# %%
fig=plt.figure(figsize=(20,7))
plt.stem(np.arange(len(toyota4)),np.round(c,3))
plt.xlabel('Row Index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
np.argmax(c) , np.max(c)
# Out:
# (80, 78.72950582258598)

# %% [markdown]
# Influence Plot

# %%
sma.graphics.influence_plot(model)
plt.show()

# %%
k=toyota4.shape[1]
n=toyota4.shape[0]
leverage_cutoff = (3*(k+1))/n
leverage_cutoff
# Out:
# 0.020905923344947737

# %%
toyota4[toyota4.index.isin([80])]
# Out:
#     Price  Age     KM   HP     CC  Doors  Gears  QTax  Weight
# 80  18950   25  20019  110  16000      5      5   100    1180

# %%
toyota5=toyota4.drop(toyota4.index[[80]],axis=0).reset_index(drop=True)
toyota5
# Out:
#       Price  Age     KM   HP    CC  Doors  Gears  QTax  Weight
# 0     13500   23  46986   90  2000      3      5   210    1165
# 1     13750   23  72937   90  2000      3      5   210    1165
# 2     13950   24  41711   90  2000      3      5   210    1165
# 3     14950   26  48000   90  2000      3      5   210    1165
# 4     13750   30  38500   90  2000      3      5   210    1170
# ...     ...  ...    ...  ...   ...    ...    ...   ...     ...
# 1429   7500   69  20544   86  1300      3      5    69    1025
# 1430  10845   72  19000   86  1300      3      5    69    1015
# 1431   8500   71  17016   86  1300      3      5    69    1015
# 1432   7250   70  16916   86  1300      3      5    69    1015
# 1433   6950   76      1  110  1600      5      5    19    1114
#
# [1434 rows x 9 columns]

# %%
while np.max(c)>0.5 :
    model=smf.ols('Price~Age+KM+HP+CC+Doors+Gears+QTax+Weight',data=toyota5).fit()
    (c,_)=model.get_influence().cooks_distance
    c
    np.argmax(c) , np.max(c)
    toyota5=toyota5.drop(toyota5.index[[np.argmax(c)]],axis=0).reset_index(drop=True)
    toyota5
else:
    final_model=smf.ols('Price~Age+KM+HP+CC+Doors+Gears+QTax+Weight',data=toyota5).fit()
    final_model.rsquared , final_model.aic
    print("Thus model accuracy is improved to",final_model.rsquared)
# Out:
# Thus model accuracy is improved to 0.8882395145171202

# %%
final_model.rsquared*100
# Out:
# 88.82395145171202

# %%
toyota5
# Out:
#       Price  Age     KM   HP    CC  Doors  Gears  QTax  Weight
# 0     13500   23  46986   90  2000      3      5   210    1165
# 1     13750   23  72937   90  2000      3      5   210    1165
# 2     13950   24  41711   90  2000      3      5   210    1165
# 3     14950   26  48000   90  2000      3      5   210    1165
# 4     13750   30  38500   90  2000      3      5   210    1170
# ...     ...  ...    ...  ...   ...    ...    ...   ...     ...
# 1426   7500   69  20544   86  1300      3      5    69    1025
# 1427  10845   72  19000   86  1300      3      5    69    1015
# 1428   8500   71  17016   86  1300      3      5    69    1015
# 1429   7250   70  16916   86  1300      3      5    69    1015
# 1430   6950   76      1  110  1600      5      5    19    1114
#
# [1431 rows x 9 columns]

# %% [markdown]
# Model Predictions

# %%
new_data=pd.DataFrame({'Age':72,"KM":14647,"HP":60,"CC":2000,"Doors":3,"Gears":5,"QTax":210,"Weight":1156},index=[0])
new_data
# Out:
#    Age     KM  HP    CC  Doors  Gears  QTax  Weight
# 0   72  14647  60  2000      3      5   210    1156

# %%
final_model.predict(new_data)
# Out:
# 0    10191.769076
# dtype: float64

# %%
pred_y=final_model.predict(toyota5)
pred_y
# Out:
# 0       16345.352610
# 1       15886.635544
# 2       16328.224968
# 3       15996.318854
# 4       15883.424182
#             ...
# 1426     9161.230587
# 1427     8536.091326
# 1428     8681.531063
# 1429     8793.668694
# 1430    10860.695492
# Length: 1431, dtype: float64

# %%
d2={'Prep_Models':['Model', 'final_model'],'Rsquared':[model.rsquared,final_model.rsquared]}
table=pd.DataFrame(d2)
table
# Out:
#    Prep_Models  Rsquared
# 0        Model  0.883968
# 1  final_model  0.888240
